# %% [markdown]
# <a href="https://colab.research.google.com/github/yatharthgill/k-meanclustering/blob/main/k_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('//content//sample_data//Mall_Customers (1).csv')
df= pd.DataFrame(data)
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       1   19                  15                      39
# 1             2       1   21                  15                      81
# 2             3       0   20                  16                       6
# 3             4       0   23                  16                      77
# 4             5       0   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       0   35                 120                      79
# 196         197       0   45                 126                      28
# 197         198       1   32                 126                      74
# 198         199       1   32                 137                      18
# 199         200       1   30                 137                      83
#
# [200 rows x 5 columns]

# %%
cluster_no = (i for i in range(1, 11))
wcss = []
for k in cluster_no:
  kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)
  kmeans.fit(df)
  wcss.append(kmeans.inertia_)
plt.figure(figsize=(8,6))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, init='k-means++', max_iter=300, n_init=10, random_state=0)
y_kmeans = kmeans.fit_predict(df)

plt.figure(figsize=(8,6))
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', label='Centroids', marker='X')
plt.title(f'K-Means clustering (K={optimal_k})')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-66a9e59ac486> in <cell line: 2>()
#       1 optimal_k = 4
# ----> 2 kmeans = KMeans(n_clusters=optimal_k, init='k-means++', max_iter=300, n_init=10, random_state=0)
#       3 y_kmeans = kmeans.fit_predict(df)
#       4
#       5 plt.figure(figsize=(8,6))
#
# NameError: name 'KMeans' is not defined

# %%
plt.figure(figsize=(8,6))

# Scatter plot for each cluster
for i in range(optimal_k):
    plt.scatter(df[y_kmeans == i]['Annual Income (k$)'], df[y_kmeans == i]['Spending Score (1-100)'], s=50, label=f'Cluster {i+1}')

# Plot centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', label='Centroids', marker='X')

plt.title(f'K-Means clustering (K={optimal_k})')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-72adc2b0cdd4> in <cell line: 1>()
# ----> 1 plt.figure(figsize=(8,6))
#       2
#       3 # Scatter plot for each cluster
#       4 for i in range(optimal_k):
#       5     plt.scatter(df[y_kmeans == i]['Annual Income (k$)'], df[y_kmeans == i]['Spending Score (1-100)'], s=50, label=f'Cluster {i+1}')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))

# Scatter plot for each cluster
for i in range(optimal_k):
    plt.scatter(df[y_kmeans == i]['Annual Income (k$)'], df[y_kmeans == i]['Spending Score (1-100)'], s=50, label=f'Cluster {i+1}')

# Plot centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', label='Centroids', marker='X')

plt.title(f'K-Means clustering (K={optimal_k})')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-72adc2b0cdd4> in <cell line: 4>()
#       3 # Scatter plot for each cluster
#       4 for i in range(optimal_k):
# ----> 5     plt.scatter(df[y_kmeans == i]['Annual Income (k$)'], df[y_kmeans == i]['Spending Score (1-100)'], s=50, label=f'Cluster {i+1}')
#       6
#       7 # Plot centroids
#
# NameError: name 'df' is not defined

# %%
data = pd.read_csv('//content//sample_data//Mall_Customers (1).csv')
df= pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b4b6a44b6a7a> in <cell line: 1>()
# ----> 1 data = pd.read_csv('//content//sample_data//Mall_Customers (1).csv')
#       2 df= pd.DataFrame(data)
#       3 df
#
# NameError: name 'pd' is not defined

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/Mall_Customers.csv')
df= pd.DataFrame(data)
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       1   19                  15                      39
# 1             2       1   21                  15                      81
# 2             3       0   20                  16                       6
# 3             4       0   23                  16                      77
# 4             5       0   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       0   35                 120                      79
# 196         197       0   45                 126                      28
# 197         198       1   32                 126                      74
# 198         199       1   32                 137                      18
# 199         200       1   30                 137                      83
#
# [200 rows x 5 columns]

# %%
plt.figure(figsize=(8,6))

# Scatter plot for each cluster
for i in range(optimal_k):
    plt.scatter(df[y_kmeans == i]['Annual Income (k$)'], df[y_kmeans == i]['Spending Score (1-100)'], s=50, label=f'Cluster {i+1}')

# Plot centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', label='Centroids', marker='X')

plt.title(f'K-Means clustering (K={optimal_k})')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-72adc2b0cdd4> in <cell line: 4>()
#       3 # Scatter plot for each cluster
#       4 for i in range(optimal_k):
# ----> 5     plt.scatter(df[y_kmeans == i]['Annual Income (k$)'], df[y_kmeans == i]['Spending Score (1-100)'], s=50, label=f'Cluster {i+1}')
#       6
#       7 # Plot centroids
#
# NameError: name 'y_kmeans' is not defined

# %%
cluster_no = (i for i in range(1, 11))
wcss = []
for k in cluster_no:
  kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)
  kmeans.fit(df)
  wcss.append(kmeans.inertia_)
plt.figure(figsize=(8,6))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
plt.figure(figsize=(8,6))

# Scatter plot for each cluster
for i in range(optimal_k):
    plt.scatter(df[y_kmeans == i]['Annual Income (k$)'], df[y_kmeans == i]['Spending Score (1-100)'], s=50, label=f'Cluster {i+1}')

# Plot centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', label='Centroids', marker='X')

plt.title(f'K-Means clustering (K={optimal_k})')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-72adc2b0cdd4> in <cell line: 4>()
#       3 # Scatter plot for each cluster
#       4 for i in range(optimal_k):
# ----> 5     plt.scatter(df[y_kmeans == i]['Annual Income (k$)'], df[y_kmeans == i]['Spending Score (1-100)'], s=50, label=f'Cluster {i+1}')
#       6
#       7 # Plot centroids
#
# NameError: name 'y_kmeans' is not defined

# %%
optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, init='k-means++', max_iter=300, n_init=10, random_state=0)
y_kmeans = kmeans.fit_predict(df)

# %%
plt.figure(figsize=(8,6))

# Scatter plot for each cluster
for i in range(optimal_k):
    plt.scatter(df[y_kmeans == i]['Annual Income (k$)'], df[y_kmeans == i]['Spending Score (1-100)'], s=50, label=f'Cluster {i+1}')

# Plot centroids
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', label='Centroids', marker='X')

plt.title(f'K-Means clustering (K={optimal_k})')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
